# %% [markdown]
# ![store checkout flowchart.png](attachment:14e789fe-4a12-41db-8de0-e61a1d849b7c.png)

# %% [markdown]
# ![morning routine flowchart.png](attachment:50a62fea-3877-439a-ac1d-ec7d959fc372.png)
