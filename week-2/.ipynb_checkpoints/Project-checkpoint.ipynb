# %% [markdown]
# #Project1A
# ![store checkout flowchart.png](attachment:523ddcdd-ed94-4df8-8785-3eed12a4670e.png)
# GET groceries from store
# INPUT the groceries you got
# COMPUTE total cost
# INPUT payment
# GET purchased goods and receipt
# END

# %% [markdown]
# #Project1B
# ![morning routine flowchart.png](attachment:5d50e352-a83e-46ad-82ce-4bbabae4cb2f.png)

# %%
#Project1C
INPUT name_1
INPUT age_1
INPUT name_2
INPUT age_2
COMPUTE temp = name_1
COMPUTE name_1 = name_2
COMPUTE name_2 = temp
